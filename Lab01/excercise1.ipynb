# %% [markdown]
# Piotr Pawełczak Lab01, ex 1
#
# - Import Data1.csv file to python.
# - Set first column as the index.
# - Plot all columns as time series.
# - Plot histograms of all columns, verify bin size. Plot all on a single, faceted plot.
# - Plot KDE-s (Kernel Denisty Estimators) for all columns.
# - Repeat analysis for columns $\theta_1$-$\theta_4$ in 2018.

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Import data and set first column as the index

# %%
df = pd.read_csv("Data1.csv", index_col=0)
df.head()
# Out:
#              theta_1   theta_2   theta_3   theta_4   theta_5   theta_6
# 2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908  0.902579
# 2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288  1.930909
# 2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351  2.449691
# 2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518  1.182085
# 2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092  1.742433

# %% [markdown]
# Plot all columns as time series

# %%
df.plot(grid=True, figsize=(20,8), subplots=True, layout=(3,2), sharex=False)
plt.show()

# %% [markdown]
# Plot histograms of all colums

# %%
df.hist(bins=20, figsize=(15,10))
plt.show()

# %% [markdown]
# Plot KDE for all colums

# %%
df.plot.kde(subplots=True, grid=True, layout=(3,2), figsize=(15,10))
plt.show()

# %% [markdown]
# Repeat analysis for theta1-theta4 in 2018
# - time series
# - histogram
# - kde

# %%
df_2018 = df.loc['2018-01-01':'2018-12-31', "theta_1":"theta_4"]
df_2018.plot(grid=True, figsize=(20,6), subplots=True, layout=(2,2), sharex=False)
plt.show()

# %%
df_2018.hist(bins=30, figsize=(10,10))
plt.show()

# %%
df_2018.plot.kde(subplots=True, layout=(2,2), figsize=(10,10), grid=True, sharex=False)
plt.show()
